# %% [markdown]
# # Assignment

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('players_22.csv')
# Out:
# /var/folders/_2/s202dmbn69l8tld_v6klnvjh0000gn/T/ipykernel_72528/3399434548.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('players_22.csv')

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %% [markdown]
# Well, not everyone plays football or knows everything about it, so i will write some clarifications.
#
# In football, player positions corresponds to these positions:-
#
# ![](https://www.fifplay.com/img/public/positions.jpg)

# %% [markdown]
# In this dataset, you have 1 row each for every football player in the game FIFA 22, For every player we have :-
# - Name
# - Weight
# - Height
# - Salary
# - Overall (This is an overall score of how good the player is)
# - Potential (In FIFA, if you play career mode, players evolve and their overall scores improve, potential refers to how good a player can get, not what he is currently)
#
# Then we have most other options like:-
# - Heading (How well can the player head the ball)
# - Standing tackle (How well can the player do a standing tackle - defense)
# - Sliding tackle (How well can the player do a sliding tackle - defense)
#
# And many many more

# %% [markdown]
# # Question
#
# This dataset is very rich, meaning you can get a lot of insights from this data.
#
# So, i have 2 questions for you.
# 1. Open ended
#     - Give me some insights from this data. (Totally open ended, dazzle me with your brilliance ^_^ )
# 2. You are hired by Real Madrid, and they want you to scout the best players possible
#     - They are looking young players, not over 26
#     - They are looking for 4 players
#         - 1 for Goalkeeper
#         - 1 Defender (Could be any position)
#         - 1 Midfielder (Could be any position)
#         - 1 Attacker (Could be any position)
#
#
#
# ![](https://media.tenor.com/GFVJq3zf6GYAAAAC/dazzle-me-virgil-van-cleef.gif)

# %% [markdown]
# ![](https://media4.giphy.com/media/7Sh3Pt6R9ELubdoH3K/giphy.gif?cid=ecf05e47bmdkhuv0r4y0ct7szjif1mlpsb9jnj5cuvox2ar0&rid=giphy.gif&ct=g)
# # ANSWER 1

# %%
df.dtypes
# Out:
# sofifa_id            int64
# player_url          object
# short_name          object
# long_name           object
# player_positions    object
#                      ...
# player_face_url     object
# club_logo_url       object
# club_flag_url       object
# nation_logo_url     object
# nation_flag_url     object
# Length: 110, dtype: object

# %%
print(df.describe())
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   19239.000000  19239.000000  19239.000000  1.916500e+04   19178.000000
# mean   231468.086959     65.772182     71.079370  2.850452e+06    9017.989363
# std     27039.717497      6.880232      6.086213  7.613700e+06   19470.176724
# min        41.000000     47.000000     49.000000  9.000000e+03     500.000000
# 25%    214413.500000     61.000000     67.000000  4.750000e+05    1000.000000
# 50%    236543.000000     66.000000     71.000000  9.750000e+05    3000.000000
# 75%    253532.500000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     93.000000     95.000000  1.940000e+08  350000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  19239.000000  19239.000000  19239.000000   19178.000000  19178.000000
# mean      25.210822    181.299704     74.943032   50580.498123      1.354364
# ...

# %% [markdown]
# ![](https://media.tenor.com/sIn-OUSzkBcAAAAd/a-lot-of-information-david.gif)

# %%
sns.countplot(y ='work_rate', data = df, palette = "Set1")
# Out:
# <Axes: xlabel='count', ylabel='work_rate'>

# %% [markdown]
# ### Players with medium/medium work rate have the most count.

# %%
sns.displot(df, x="overall", hue="preferred_foot",multiple='stack', bins=10)

# %% [markdown]
# ### Count of overall score categorized by preferred foot.

# %% [markdown]
# # 1. Correlation Between Overall Score (out of 100) and international Reputation (out of 5).

# %%
plt.bar(df['international_reputation'],df['overall'], color='maroon')
# Out:
# <BarContainer object of 19239 artists>

# %% [markdown]
# ###  - As we can see above the overall score has a direct and positive correlation with international reputation.
# ###  - More the overall score results in more of international reputation.
# ![](https://media4.giphy.com/media/ZdrDcyOBZjoZHkvpYx/200w.webp?cid=ecf05e47iiowmiqxgx0fmcaxoscqt3xltcfzgeqjglwbyy2u&rid=200w.webp&ct=g)

# %% [markdown]
# # 2. Correlation between International reputation and Wages in euro.

# %%
plt.bar(df['international_reputation'],df['wage_eur'], color='green')
# Out:
# <BarContainer object of 19239 artists>

# %% [markdown]
# ### As we can see, the players' reputation and their revenue are directly correlated. It indicates that income increases with the reputation.
# ### But why players with ratings of 5 are paid less than those with ratings of 4?

# %%
plt.bar(df['international_reputation'],df['value_eur'], color='red')
# Out:
# <BarContainer object of 19239 artists>

# %% [markdown]
# ### players with rating of 5 might be paid less than those of 4 becuase of their value differences, players with rating 4 have more value than rating 5 players.
#
# ![](https://media0.giphy.com/media/qWmygf9g56BEUYFkHw/200w.webp?cid=ecf05e47qkn8ri56x9tfb9nrupex44jjfl4q5r5wbkzw6zey&rid=200w.webp&ct=g)

# %% [markdown]
# # 3. Correlation between International Reputation and Age

# %%
plt.bar(df['international_reputation'],df['age'], color='orange')
# Out:
# <BarContainer object of 19239 artists>

# %% [markdown]
# ### From above we can make out that old players over age 42 approx. have been rated 1 out of 5 and all the players who are rated 5 are under the age of 40.

# %% [markdown]
# # 4. Correlation between Overall Score and Age

# %%
plt.bar(df['overall'],df['age'])

# %% [markdown]
# ### Here above we can see that players under the age of 25 have the least overall score as they are low in professional experience.
# ### Players over the age of 32 approx. have the Overall score from the range 65 - 90. Telling that players reach their prime at 30 years.
#
# ![](https://media3.giphy.com/media/W6ijtBmn4RImWFmfM1/giphy.gif?cid=ecf05e47iu6roa6e003hf3y0qfpmh0whtb3m856h5nph46p5&rid=giphy.gif&ct=g)

# %% [markdown]
# # 5. Correlation between Wages and Age.

# %%
plt.scatter(df['wage_eur'],df['age'])

# %% [markdown]
# ### The majority of highly compensated athletes are between the ages of 25 and 35, which may indicate that as athletes age, their performance begins to decline.
# ### However, athletes between the ages of 25 to 35 are more in demand  as they are both young and experienced, which accounts for their higher pay.
#
# ![](https://media.tenor.com/WYXu2z1RsM0AAAAC/ronaldo-ronaldo-skills.gif)

# %% [markdown]
# # 6. Value Count of International Reputation

# %%
explode = (0.1,0.1,0.1,0.4,0.7)
df['international_reputation'].value_counts().plot(kind='pie',explode=explode)
# Out:
# <Axes: ylabel='international_reputation'>

# %% [markdown]
# ### Most players in the dataset have the reputation of 1 and very less have 5.

# %% [markdown]
# # 7. Correlation between Position of players and Wages they are paid

# %%
df.groupby('club_position')['wage_eur'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='club_position'>

# %% [markdown]
# ### Center Forward (CF) players are paid the most wage among all other position players as even though football is a team game but still CF players have the most pressure as they have the most responsibility of scoring goals for the team.

# %% [markdown]
# # 8. Top 5 players according to Overall Score

# %%
score=df.sort_values('overall', ascending=False)
plt.barh(score['short_name'].head(),score['overall'].head())
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### These 5 players are the best in this dataset according to Overall Score with Messi at the top.
#
# ![](https://media.tenor.com/vbjObX-FBYoAAAAd/lionel-messi-soccer-player.gif)

# %% [markdown]
# # 9. Top Shooters

# %%
shooters=df.sort_values('shooting', ascending=False)
plt.bar(shooters['short_name'].head(),shooters['shooting'].head())

# %% [markdown]
# ### Shooting is of the highest essence in football, above you can see the top 5 shooters in football with Ronaldo at top as expected.
#
# ![](https://media.tenor.com/v-d2Sw0GyNAAAAAC/cristiano-ronaldo-ronaldo.gif)

# %% [markdown]
# # 10. Fastest players

# %%
P = df.groupby('pace')

# %%
df['pace'].max()

# %%
pace=df.sort_values('pace', ascending=False)
plt.bar(pace['short_name'].head(),pace['pace'].head())

# %%
P.get_group(97)

# %% [markdown]
# ### Above bar plot shows the top 5 fastest players in the dataset.
# ### Kylian Mbappe has the highest pace of 97.
#
# ![](https://media.tenor.com/rR0kkA0THW8AAAAC/mbapp%C3%A9om-kylian-mbapp%C3%A9.gif)

# %% [markdown]
# # ANSWER 2

# %% [markdown]
# # Goalkeeper Search:
#
# ## We will be selecting the goalkeeper based on the following factors:
#    - goalkeeping_diving
#    - goalkeeping_handling
#    - goalkeeping_kicking
#    - goalkeeping_reflexes
#    - goalkeeping_speed
#
#    ![](https://media.tenor.com/xeMatKp81tsAAAAC/lightning-hand-%E9%AC%BC%E5%BD%B1%E6%93%92%E6%8B%BF%E6%89%8B.gif)

# %%
df[(df['player_positions'] == 'GK') & (df['club_name'] == 'Real Madrid CF')]

# %%
df_GK=df[(df['player_positions'] == 'GK') & (df['club_name'] != 'Real Madrid CF') & (df['age'] <= 26)]

# %%
df_GK
# Out:
#        sofifa_id                                         player_url  \
# 21        230621  https://sofifa.com/player/230621/gianluigi-don...
# 127       215698  https://sofifa.com/player/215698/mike-maignan/...
# 243       211515  https://sofifa.com/player/211515/pierluigi-gol...
# 267       230869  https://sofifa.com/player/230869/unai-simon-me...
# 282       241671  https://sofifa.com/player/241671/dominik-livak...
# ...          ...                                                ...
# 19210     261958  https://sofifa.com/player/261958/xiang-gao/220002
# 19216     263340  https://sofifa.com/player/263340/harvey-wiles-...
# 19225     259213  https://sofifa.com/player/259213/dylan-da-silv...
# 19227     259646  https://sofifa.com/player/259646/arsh-shaikh/2...
# 19231     261547  https://sofifa.com/player/261547/revanth-by/22...
#
#               short_name              long_name player_positions  overall  \
# 21         G. Donnarumma   Gianluigi Donnarumma               GK       89
# ...

# %%
best_handling=df_GK.sort_values('goalkeeping_handling', ascending=False)

# %%
best_handling['long_name'].head()
# Out:
# 21     Gianluigi Donnarumma
# 243       Pierluigi Gollini
# 127            Mike Maignan
# 851            Ondřej Kolář
# 462        Pau López Sabata
# Name: long_name, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(best_handling['short_name'].head(),best_handling['goalkeeping_handling'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_kicking=df_GK.sort_values('goalkeeping_kicking', ascending=False)

# %%
best_kicking['long_name'].head()
# Out:
# 574     Kepa Arrizabalaga Revuelta
# 127                   Mike Maignan
# 363      Alejandro Remiro Gargallo
# 21            Gianluigi Donnarumma
# 4997        Vanja Milinković-Savić
# Name: long_name, dtype: object

# %%
plt.barh(best_kicking['short_name'].head(),best_kicking['goalkeeping_kicking'].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plt.barh(best_kicking['short_name'].head(),best_kicking['goalkeeping_kicking'].head())
#
# NameError: name 'best_kicking' is not defined

# %%
best_diving=df_GK.sort_values('goalkeeping_diving', ascending=False)

# %%
best_diving['long_name'].head()
# Out:
# 21          Gianluigi Donnarumma
# 363    Alejandro Remiro Gargallo
# 127                 Mike Maignan
# 243            Pierluigi Gollini
# 267          Unai Simón Mendibil
# Name: long_name, dtype: object

# %%
plt.barh(best_diving['short_name'].head(),best_diving['goalkeeping_diving'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_reflexes=df_GK.sort_values('goalkeeping_reflexes', ascending=False)
plt.barh(best_reflexes['short_name'].head(),best_reflexes['goalkeeping_reflexes'].head(), color = ['orange', 'black'])
# Out:
# <BarContainer object of 5 artists>

# %%
best_speed=df_GK.sort_values('goalkeeping_speed', ascending=False)
plt.bar(best_speed['short_name'].head(),best_speed['goalkeeping_speed'].head(), color=['green','red'])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Best Goalkeeper:
# Gianluigi Donnarumma has the best handling, reflexes and diving and also comes under top 5 in kicking.
# Without any second thought, he is the best goalkeeper available for Real Madrid.
#
# Mike Maignan is also the player who appears in top 5 under reflexes, diving and kicking. So the second choice after Gigi (Gianluigi Donnarumma) would be Mike Maignan if Gigi is not available.
#
# ![](https://media4.giphy.com/media/YlSB9luhIsDeJn3pz3/giphy.gif?cid=ecf05e47862n41qkvpzqf28zb5cdxekmvubab2xhs8aed9z8&rid=giphy.gif&ct=g)

# %% [markdown]
# # Defender Search:

# %%
df_def=df[(df['club_name'] != 'Real Madrid CF') & (df['age'] <= 26)]

# %% [markdown]
# # We will be selecting the defenders based on the following factors:
#    - defending_marking_awareness
#    - defending_standing_tackle
#    - defending_sliding_tackle
#    - defending
#
#    ![](https://media.tenor.com/Wtrnjrt-vRgAAAAC/tackle-soccer.gif)

# %%
best_dma=df_def.sort_values('defending_marking_awareness', ascending=False)
plt.bar(best_dma['short_name'].head(),best_dma['defending_marking_awareness'].head(), color = ['orange', 'black'])
# Out:
# <BarContainer object of 5 artists>

# %%
best_dst=df_def.sort_values('defending_standing_tackle', ascending=False)
plt.barh(best_dst['short_name'].head(),best_dst['defending_standing_tackle'].head(), color = ['red', 'green'])
# Out:
# <BarContainer object of 5 artists>

# %%
best_dslt=df_def.sort_values('defending_sliding_tackle', ascending=False)
plt.barh(best_dslt['short_name'].head(),best_dslt['defending_sliding_tackle'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_def=df_def.sort_values('defending', ascending=False)
plt.bar(best_def['short_name'].head(),best_def['defending'].head())
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Best Defender:
# Ruben Dias has the best marking awareness, defending and also is second in standing tackle.
# He is the best defender available for Real Madrid.
#
# W. Ndidi is also a player who has the best standing tackle and appears under top 5 in marking awareness and defending.  He is the second best option if Ruben is not available.
#
# ![](https://media.tenor.com/DLDWZopZI9AAAAAC/dias-ruben-dias.gif)

# %% [markdown]
# # Midfielder Search:

# %% [markdown]
# The most running is required of midfielders, additionally they also possess the ball the most. In order to choose the best option, we must consider a few broad factors.
#
#    - pace
#    - Defending
#    - shooting
#    - passing
#    - dribbling
#    - Physic

# %%
df_mid=df[(df['club_name'] != 'Real Madrid CF') & (df['age'] <= 26)]

# %%
best_pac=df_mid.sort_values('pace', ascending=False)
plt.barh(best_pac['short_name'].head(),best_pac['pace'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_deff=df_mid.sort_values('defending', ascending=False)
plt.bar(best_deff['short_name'].head(),best_deff['pace'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_shoo=df_mid.sort_values('shooting', ascending=False)
plt.barh(best_shoo['short_name'].head(),best_shoo['shooting'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_pass=df_mid.sort_values('passing', ascending=False)
plt.barh(best_pass['short_name'].head(),best_pass['passing'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_dribb=df_mid.sort_values('dribbling', ascending=False)
plt.barh(best_dribb['short_name'].head(),best_dribb['dribbling'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_phy=df_mid.sort_values('physic', ascending=False)
plt.bar(best_phy['short_name'].head(),best_phy['dribbling'].head())
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Best Midfielder:
#
#  Kylian Mbappe should be the best option to choose but he is a striker so the best midfilder from this analysis would be Bruno Fernandes who is a atacking midfielder.
#
#  ![](https://media.tenor.com/F6eN_DSx8XoAAAAM/bruno-bruno-fernandes.gif)

# %% [markdown]
# # Attacker Search:

# %% [markdown]
# # We will be selecting the attacker based on the following factors:
#    - attacking_crossing
#    - attacking_finishing
#    - attacking_heading_accuracy
#    - attacking_short_passing
#    - attacking_volleys
#    - shooting
#    - pace
#
#    ![](https://media.tenor.com/T2borIV-rlMAAAAd/cristiano-cr7.gif)

# %%
df_att=df[(df['club_name'] != 'Real Madrid CF') & (df['age'] <= 26)]

# %%
best_attc=df_att.sort_values('attacking_crossing', ascending=False)
plt.barh(best_attc['short_name'].head(),best_attc['attacking_crossing'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_attf=df_att.sort_values('attacking_finishing', ascending=False)
plt.bar(best_attf['short_name'].head(),best_attf['attacking_finishing'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_attha=df_att.sort_values('attacking_heading_accuracy', ascending=False)
plt.barh(best_attha['short_name'].head(),best_attha['attacking_heading_accuracy'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_attsp=df_att.sort_values('attacking_short_passing', ascending=False)
plt.barh(best_attsp['short_name'].head(),best_attsp['attacking_short_passing'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_attv=df_att.sort_values('attacking_volleys', ascending=False)
plt.barh(best_attv['short_name'].head(),best_attv['attacking_volleys'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_shoo2=df_att.sort_values('shooting', ascending=False)
plt.barh(best_shoo2['short_name'].head(),best_shoo2['shooting'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
best_pac2=df_att.sort_values('pace', ascending=False)
plt.bar(best_pac2['short_name'].head(),best_pac2['pace'].head())
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Best Attacker:
#
# Kylian Mbappe and Erling Haaland are the best options to choose for attacker position.
#
# ![](https://media.tenor.com/QjWpD_j2WUgAAAAd/haaland-erling-haaland.gif)

# %% [markdown]
# ![](https://media.tenor.com/M7tHMsfqoAoAAAAd/i-think-i-did-a-very-good-job-adam.gif)

# %% [markdown]
# # FIN
